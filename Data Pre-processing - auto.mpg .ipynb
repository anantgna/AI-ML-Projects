# %% [markdown]
# **Assignment - 2**
# * Submitted by - Anant Kumar Jain
# * Btech A.I
# * ADV3ARI0008

# %%
#Importing Libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
Columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin']

# %%
#Reading Dataset auto-mpg.data
mpg_dataset = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/auto-mpg.data',
sep = ' ', skipinitialspace = True, comment = '\t' , names = Columns, na_values = '?' )

# %% [markdown]
# **1. Displaying Dataset**

# %%
display(mpg_dataset)
# Out:
#       mpg  cylinders  displacement  ...  acceleration  model year  origin
# 0    18.0          8         307.0  ...          12.0          70       1
# 1    15.0          8         350.0  ...          11.5          70       1
# 2    18.0          8         318.0  ...          11.0          70       1
# 3    16.0          8         304.0  ...          12.0          70       1
# 4    17.0          8         302.0  ...          10.5          70       1
# ..    ...        ...           ...  ...           ...         ...     ...
# 393  27.0          4         140.0  ...          15.6          82       1
# 394  44.0          4          97.0  ...          24.6          82       2
# 395  32.0          4         135.0  ...          11.6          82       1
# 396  28.0          4         120.0  ...          18.6          82       1
# 397  31.0          4         119.0  ...          19.4          82       1
#
# [398 rows x 8 columns]

# %% [markdown]
# **2. Displaying Shape, Size, Dimension Of Dataset**

# %%
# Shape of Dataset
shape = mpg_dataset.shape
print("Shape of Dataset - ",shape)
# Out:
# Shape of Dataset -  (398, 8)

# %%
# Size of Dataset
size = mpg_dataset.size
print("Size of Dataset - ",size)
# Out:
# Size of Dataset -  3184

# %%
# Dimension of Dataset
dim = mpg_dataset.ndim
print("Dimension of Dataset - ",dim)
# Out:
# Dimension of Dataset -  2

# %%
# Information about Dataset
inf = mpg_dataset.info()
print("Information about Dataset - ",inf)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 25.0 KB
# Information about Dataset -  None

# %% [markdown]
# **3. Finding Missing Values and Handling them**

# %%
#Checking Missing Elements from Dataset
mpg_dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
#Checking Missing Values in dataset in coloumn Horsepower
mpg_dataset['horsepower'].unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
#Checking Missing Values in dataset in coloumn Horsepower
mpg_dataset['origin'].unique()
# Out:
# array([1, 3, 2])

# %%
#Mean from the Horsepower Column 
mean_val = np.round(np.mean(mpg_dataset['horsepower']), 0)

# %%
mean_val
# Out:
# 104.0

# %%
#Replacing nan in columns from Mean
mpg_dataset['horsepower'] = mpg_dataset['horsepower'].replace(np.nan, mean_val)

# %%
mpg_dataset.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %% [markdown]
# **4. Handling Outliers**

# %%
#Using Boxplot to find the outliers
plt.figure(figsize = (20,40) )
sns.boxplot(data = mpg_dataset)

# %% [markdown]
# **Handling Outliers In Horsepower**

# %%
#A User Defined Function

def find_outliers(input_df) :
  q1 = input_df.quantile(0.25)
  q3 = input_df.quantile(0.75)

  iqr = q3 - q1
  min_range = q1 - 1.5 * iqr
  max_range = q3 + 1.5 * iqr

  # indexes of outliers
  
  outliers_indices = list(input_df.index[(input_df < min_range) | (input_df > max_range)])
  outliers_values = list(input_df[outliers_indices])
  count = len(outliers_values)

  print(" Min Range : %i" %min_range)
  print(" Max Range : %i" %max_range)
  print(" Total No. of Outliers = ", count)

  return outliers_indices, outliers_values

# %%
find_outliers(mpg_dataset['horsepower'])
# Out:
#  Min Range : 25
#  Max Range : 161
#  Total No. of Outliers =  10
# ([1, 10, 38, 43, 62, 104, 105, 156, 230, 263],
#  [165.0, 170.0, 165.0, 170.0, 165.0, 167.0, 170.0, 170.0, 170.0, 165.0])

# %%
mean_val = np.mean([mpg_dataset['horsepower']])

# %%
mpg_dataset['horsepower'] = np.where(mpg_dataset['horsepower'] > 198, mean_val, mpg_dataset['horsepower'])

# %%
# We have already find mean above as mean_val 
#Here we are replacing vakues above maximum from outliers to mean value
mpg_dataset['horsepower'] = np.where(mpg_dataset['horsepower'] > 173, mean_val, mpg_dataset['horsepower'])

# %%
plt.figure(figsize = (20,40) )
sns.boxplot(data = mpg_dataset)

# %%
#Hence We have handeled outliers
