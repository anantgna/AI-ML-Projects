# %%
import pandas as pd

# %%
nyc = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/DataStructures/4_HashTable_2_Collisions/Solution/nyc_weather.csv")

# %%
nyc
# Out:
#      date  temperature(F)
# 0   Jan 1              27
# 1   Jan 2              31
# 2   Jan 3              23
# 3   Jan 4              34
# 4   Jan 5              37
# 5   Jan 6              38
# 6   Jan 7              29
# 7   Jan 8              30
# 8   Jan 9              35
# 9  Jan 10              30

# %%
sum = 0
for i in range(0,7):
  sum += nyc['temperature(F)'][i]

# %%
sum /7
# Out:
# 31.285714285714285

# %%
nyc['temperature(F)'].max()
# Out:
# 38
